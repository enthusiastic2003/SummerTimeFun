# %% [markdown]
# <a href="https://colab.research.google.com/github/enthusiastic2003/SummerTimeFun/blob/main/venus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import unicodedata

import re


# Convert the unicode sequence to ascii
def unicode_to_ascii(s):

  # Normalize the unicode string and remove the non-spacking mark
  return ''.join(c for c in unicodedata.normalize('NFD', s)
      if unicodedata.category(c) != 'Mn')

# Preprocess the sequence
def preprocess_sentence(w):

  # Clean the sequence
  w = unicode_to_ascii(w.lower().strip())

  # Create a space between a word and the punctuation following it also place a space between the punctuation and the following word. Note that punctuation also includes |

  w = re.sub(r"([?.!।])", r" \1 ", w)

  # Add a start and stop token to detect the start and end of the sequence
  w = '<start> ' + w + ' <end>'
  return w

# %%
import io

# Create the Dataset
def create_dataset(path):
  lines = io.open(path, encoding='UTF-8').read().strip().split('\n')

  # Loop through lines (sequences) and extract the English and French sequences. Store them as a word-pair
  word_pairs = [[preprocess_sentence(w) for w in l.split('\t', 2)[:-1]]  for l in lines]
  return zip(*word_pairs)

# %%
path_to_file='fra_new.txt'

# %%
lines = io.open(path_to_file, encoding='UTF-8').read().strip().split('\n')
print(lines[0])
print(preprocess_sentence(lines[0].split('\t', 2)[0]))
print(preprocess_sentence(lines[0].split('\t', 2)[1]))
# Out:
# Go.	Va !	CC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #1158250 (Wittydev)
# <start> go .  <end>
# <start> va  !  <end>

# %%
en, fra = create_dataset(path_to_file)
print(en[0])
print(fra[0])
# Out:
# <start> go .  <end>
# <start> va  !  <end>

# %%
import tensorflow as tf

# Convert sequences to tokenizers
def tokenize(lang):
  lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(
      filters='')

  # Convert sequences into internal vocab
  lang_tokenizer.fit_on_texts(lang)

  # Convert internal vocab to numbers
  tensor = lang_tokenizer.texts_to_sequences(lang)

  # Pad the tensors to assign equal length to all the sequences
  tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,
                                                         padding='post')

  return tensor, lang_tokenizer

# %%
# Load the dataset
def load_dataset(path, num_examples=None):

  # Create dataset (targ_lan = English, inp_lang = French)
  inp_lang,targ_lang = create_dataset(path)

  # Tokenize the sequences
  input_tensor, inp_lang_tokenizer = tokenize(inp_lang)
  target_tensor, targ_lang_tokenizer = tokenize(targ_lang)

  return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %%
# Consider 50k examples
num_examples = 50000
input_tensor, target_tensor, inp_lang, targ_lang = load_dataset(path_to_file)

# Calculate max_length of the target tensors
max_length_targ, max_length_inp = target_tensor.shape[1], input_tensor.shape[1]

# %%
print(max_length_targ, max_length_inp)
# Out:
# 17 11

# %%
print(input_tensor[0], target_tensor.shape)
# Out:
# [ 1 31  3  2  0  0  0  0  0  0  0] (58184, 17)

# %%
from sklearn.model_selection import train_test_split

# Create training and validation sets using an 80/20 split
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, target_tensor, test_size=0.2)

print(len(input_tensor_train), len(target_tensor_train), len(input_tensor_val), len(target_tensor_val))
# Out:
# 46547 46547 11637 11637

# %%
print(input_tensor_train)
print(inp_lang)
# Out:
# [[  1  53  32 ...   0   0   0]
#  [  1   7  20 ...   0   0   0]
#  [  1  49  64 ...   0   0   0]
#  ...
#  [  1  69  15 ...   0   0   0]
#  [  1  21  52 ...   0   0   0]
#  [  1 265   9 ...   0   0   0]]
# <keras.src.preprocessing.text.Tokenizer object at 0x7f4d90108c40>

# %%
# Show the mapping b/w word index and language tokenizer
def convert(lang, tensor):
  for t in tensor:
    if t != 0:
      print ("%d ----> %s" % (t, lang.index_word[t]))

print ("Input Language; index to word mapping")
convert(inp_lang, input_tensor_train[0])
print ()
print ("Target Language; index to word mapping")
convert(targ_lang, target_tensor_train[0])
# Out:
# Input Language; index to word mapping
# 1 ----> <start>
# 53 ----> i'll
# 32 ----> be
# 60 ----> out
# 48 ----> of
# 614 ----> town
# 3 ----> .
# 2 ----> <end>
#
# Target Language; index to word mapping
# 1 ----> <start>
# 4 ----> je
# 10 ----> ne
# 361 ----> serai
# 7 ----> pas
# 24 ----> en
# 442 ----> ville
# 3 ----> .
# 2 ----> <end>

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 64
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
embedding_dim = 256
units = 1024
vocab_inp_size = len(inp_lang.word_index) + 1
vocab_tar_size = len(targ_lang.word_index) + 1

# %%
# !mkdir ./utils

# %%
import tensorflow as tf

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.model_selection import train_test_split

import unicodedata
import re
import numpy as np
import os
import io
import time
from utils.dataset import NMTDataset
from tensorflow.python.ops import math_ops
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-f51ffe85d298> in <cell line: 13>()
#      11 import io
#      12 import time
# ---> 13 from utils.dataset import NMTDataset
#      14 from tensorflow.python.ops import math_ops
#      15
#
# ModuleNotFoundError: No module named 'utils.dataset'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
BUFFER_SIZE = 32000
BATCH_SIZE = 64
num_examples = 30000

dataset_creator = NMTDataset('en-spa')
train_dataset, val_dataset, inp_lang, targ_lang = dataset_creator.call(num_examples, BUFFER_SIZE, BATCH_SIZE)

# %%
# Size of input and target batches
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([64, 11]), TensorShape([64, 17]))

# %%
import tensorflow as tf

class Encoder(tf.keras.layers.Layer):
    def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
        super(Encoder, self).__init__()
        self.batch_sz = batch_sz
        self.enc_units = enc_units

        # Embedding layer
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)

        # GRU-bidirectional Layer
        self.gru = tf.keras.layers.GRU(self.enc_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')


    # Encoder network comprises an Embedding layer followed by an LSTM layer
    def call(self, x, hidden):
        x = self.embedding(x)
        output_all_cells, state = self.gru(x, initial_state=hidden)
        state = tf.expand_dims(state, 1)
        return output_all_cells, state

    # To initialize the hidden state
    def initialize_hidden_state(self):
      return tf.zeros((self.batch_sz, self.enc_units))

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

sample_hidden = encoder.initialize_hidden_state()
sample_output, enc_states = encoder(example_input_batch, sample_hidden)

print ('Encoder output shape: (batch size, sequence length, units) {}'.format(sample_output.shape))
print('Encoder state shape: {}'.format(enc_states.shape))
# Out:
# Encoder output shape: (batch size, sequence length, units) (64, 11, 1024)
# Encoder state shape: (64, 1, 1024)

# %%
import tensorflow as tf

class PayAttention(tf.keras.layers.Layer):
    def __init__(self, units_enc, units_dec,enc_length):
        super(PayAttention, self).__init__() #Call initializer of the superclass
        self.units_enc=units_enc
        self.units_dec=units_dec
        self.enc_length=enc_length


    def call(self, enc_output, dec_states):


        # enc_output= (64, 23, 1024)
        # x=(1, units_dec)
        # x=(1,1)
        x=tf.matmul(dec_states,enc_output, transpose_b=True)
        #weights=(64,23,scalr)
        weights=x

        # softmaxed_weights = (64,1,23)
        softmaxed_weights = tf.nn.softmax(weights, axis=2)
        softmaxed_weights = tf.transpose(softmaxed_weights, perm=[0,2,1])
        context_vector = tf.reduce_sum(softmaxed_weights*enc_output, axis=1)
        return context_vector, softmaxed_weights

# %%
class DecoderLayer(tf.keras.layers.Layer):
    def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz, enc_units,inp_length):
        super().__init__()
        self.batch_sz=batch_sz
        self.dec_units=dec_units
        self.enc_units=enc_units
        self.embedding_dim=embedding_dim
        self.vocab_size=vocab_size
        self.inp_length=inp_length

        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)

        self.attention = PayAttention(self.enc_units , self.dec_units, self.inp_length)

        self.gru = tf.keras.layers.GRU(self.dec_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
        self.fc = tf.keras.layers.Dense(vocab_size)

    def call(self, enc_output, dec_input, dec_internal_state=None):
        # hidden is the hidden states of all the units in the encoder
        # context_vector is the context vector from the attention layer
        # dec_input is the input to the decoder

        # Now, first embed the decoder input
        if dec_internal_state==None:
          dec_internal_state = self.gru.get_initial_state(inputs=dec_input)
          dec_internal_state = tf.cast(dec_internal_state, tf.float32)

        # Get Context for each target token generation
        context_vector, softmaxed_weights = self.attention(enc_output, dec_internal_state)

        # Embed the decoder input
        embed_dec_input=self.embedding(dec_input)

        # Context + input = input to the GRU
        x = tf.concat([tf.expand_dims(context_vector, 1), embed_dec_input], axis=-1)

        # Pass through a GRU layer
        output, state = self.gru(x)

        # Pass through a dense layer to get the probabilities distribution over the target vocabulary
        output = tf.reshape(output, (-1, output.shape[2]))
        x = self.fc(output)
        state = tf.expand_dims(state, 1)
        return x, state , softmaxed_weights

# %%
decoder = DecoderLayer(vocab_tar_size ,embedding_dim, units, BATCH_SIZE, units, max_length_inp)

# %%
dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)
prob_dist, states_decode, weights = decoder(sample_output, dec_input, enc_states )
#decoder(sample_output, dec_input, None )

# %%
print(states_decode.shape)
# Out:
# (64, 1, 1024)

# %%
print(weights[0])
# Out:
# tf.Tensor(
# [[0.08968794]
#  [0.08991764]
#  [0.08947254]
#  [0.08964249]
#  [0.08912943]
#  [0.08935861]
#  [0.08961659]
#  [0.09079557]
#  [0.09077422]
#  [0.09474929]
#  [0.0968556 ]], shape=(11, 1), dtype=float32)

# %%
# Now we will define the Model using the layers we have already defined.
#class BenLish(tf.keras.Model):
#  def __init__(self, vocab_size_inp, vocab_size_tar, embedding_dim, dec_units, batch_sz, enc_units,inp_length):
#    super().__init__()
#    self.encoder = Encoder(vocab_size_inp, embedding_dim, enc_units, batch_sz)
#    self.decoder = DecoderLayer(vocab_size_tar ,embedding_dim, dec_units, batch_sz, dec_units, inp_length)

#  def call(self, sentence):

# %%
#Now we define the loss function. The loss function is the cross entropy loss function. The cross entropy loss function is defined as follows:
#-sum(y_true * log(y_pred), axis=-1)
import numpy as np

with tf.device('/gpu:0'):
  optimizer = tf.optimizers.Adam()

  def loss_function(real, pred):
      mask = 1 - np.equal(real, 0)
      loss_ = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=real, logits=pred) * mask
      return tf.reduce_mean(loss_)

# %%
#Now we run the training loop
with tf.device('/gpu:0'):
  optimizer = tf.keras.optimizers.Adam()
  loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

  decoder = DecoderLayer(vocab_tar_size ,embedding_dim, units, BATCH_SIZE, units, max_length_inp)
  encoder=Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

  import os
  checkpoint_dir = './training_checkpoints'
  checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
  checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                  encoder=encoder,
                                  decoder=decoder)

  def train_step(inp, targ):
      loss=0

      with tf.GradientTape() as tape:
          print("INPUT: ", inp.shape)
          # Initialize the hidden state of the encoder and pass the input to the encoder
          hidden_initialize = encoder.initialize_hidden_state()
          enc_output, enc_hidden = encoder(inp, hidden_initialize)

          dec_hidd=enc_hidden

          # Initialize the hidden state of the decoder
          dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

          # Teacher forcing - feeding the target as the next input
          for t in range(1, targ.shape[1]):
              # passing enc_output to the decoder
              prob_dist, dec_hidd, weights = decoder(sample_output, dec_input, dec_hidd )
              loss += loss_function(targ[:, t], prob_dist)
              # using teacher forcing
              dec_input = tf.expand_dims(targ[:, t], 1)



      batch_loss = (loss / int(targ.shape[1]))
      variables = encoder.trainable_variables + decoder.trainable_variables
      gradients = tape.gradient(loss, variables)
      optimizer.apply_gradients(zip(gradients, variables))
      return batch_loss

# %%
print(steps_per_epoch)
# Out:
# 727

# %%
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
with tf.device('/gpu:0'):
  EPOCHS=30
  import time

  for epoch in range(EPOCHS):
      start = time.time()
      total_loss = 0

      for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
          batch_loss = train_step(inp, targ)
          total_loss += batch_loss
          print(targ.shape)
          print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                          batch,
                                                          batch_loss.numpy()))
      # saving (checkpoint) the model every 2 epochs
      if (epoch + 1) % 2 == 0:
          checkpoint.save(file_prefix = checkpoint_prefix+str(epoch))

      print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                        total_loss / steps_per_epoch))
      print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# INPUT:  (64, 11)
# WARNING:tensorflow:5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7f4d1d8bfb50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7f4d1d8bfb50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# (64, 17)
# Epoch 1 Batch 0 Loss 3.2724
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 1 Loss 3.1274
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 2 Loss 3.2640
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 3 Loss 3.3906
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 4 Loss 3.4265
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 5 Loss 3.3311
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 6 Loss 3.3186
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 7 Loss 3.2849
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 8 Loss 3.3095
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 9 Loss 3.2574
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 10 Loss 3.3554
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 11 Loss 3.3125
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 12 Loss 3.3160
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 13 Loss 3.2659
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 14 Loss 2.9791
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 15 Loss 2.9851
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 16 Loss 2.9893
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 17 Loss 2.8766
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 18 Loss 2.9406
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 19 Loss 2.7233
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 20 Loss 2.5763
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 21 Loss 2.5063
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 22 Loss 2.5078
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 23 Loss 2.4907
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 24 Loss 2.4080
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 25 Loss 2.2287
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 26 Loss 2.2056
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 27 Loss 2.2764
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 28 Loss 2.0943
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 29 Loss 1.9701
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 30 Loss 2.0723
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 31 Loss 2.0512
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 32 Loss 2.0031
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 33 Loss 1.9380
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 34 Loss 2.0075
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 35 Loss 2.0222
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 36 Loss 1.9860
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 37 Loss 2.1045
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 38 Loss 1.9236
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 39 Loss 1.9285
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 40 Loss 1.9248
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 41 Loss 1.9025
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 42 Loss 2.0180
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 43 Loss 1.9074
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 44 Loss 1.8492
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 45 Loss 1.7603
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 46 Loss 1.8042
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 47 Loss 1.8489
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 48 Loss 1.9385
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 49 Loss 1.9749
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 50 Loss 1.7686
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 51 Loss 1.8395
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 52 Loss 1.8034
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 53 Loss 1.7878
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 54 Loss 1.8074
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 55 Loss 1.7707
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 56 Loss 1.6844
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 57 Loss 1.7725
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 58 Loss 1.7807
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 59 Loss 1.7749
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 60 Loss 1.7191
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 61 Loss 1.7149
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 62 Loss 1.7467
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 63 Loss 1.6538
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 64 Loss 1.7396
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 65 Loss 1.7269
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 66 Loss 1.8279
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 67 Loss 1.7366
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 68 Loss 1.7508
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 69 Loss 1.7467
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 70 Loss 1.7183
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 71 Loss 1.6630
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 72 Loss 1.8789
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 73 Loss 1.6906
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 74 Loss 1.7461
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 75 Loss 1.6308
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 76 Loss 1.6446
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 77 Loss 1.6742
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 78 Loss 1.6237
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 79 Loss 1.6842
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 80 Loss 1.7444
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 81 Loss 1.6983
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 82 Loss 1.6440
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 83 Loss 1.7110
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 84 Loss 1.7119
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 85 Loss 1.6914
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 86 Loss 1.7110
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 87 Loss 1.5655
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 88 Loss 1.7622
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 89 Loss 1.6064
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 90 Loss 1.6453
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 91 Loss 1.6646
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 92 Loss 1.5732
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 93 Loss 1.5999
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 94 Loss 1.7342
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 95 Loss 1.6504
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 96 Loss 1.6726
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 97 Loss 1.6450
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 98 Loss 1.7121
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 99 Loss 1.6212
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 100 Loss 1.6004
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 101 Loss 1.7569
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 102 Loss 1.7666
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 103 Loss 1.6946
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 104 Loss 1.6118
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 105 Loss 1.5899
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 106 Loss 1.6747
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 107 Loss 1.6098
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 108 Loss 1.5223
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 109 Loss 1.5986
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 110 Loss 1.6696
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 111 Loss 1.6414
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 112 Loss 1.7108
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 113 Loss 1.7347
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 114 Loss 1.6194
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 688 Loss 1.3586
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 689 Loss 1.3555
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 690 Loss 1.3496
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 691 Loss 1.3483
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 692 Loss 1.2750
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 693 Loss 1.3547
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 694 Loss 1.3371
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 695 Loss 1.4025
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 696 Loss 1.3884
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 697 Loss 1.3983
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 698 Loss 1.3401
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 699 Loss 1.4103
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 700 Loss 1.3464
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 701 Loss 1.4008
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 702 Loss 1.3297
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 703 Loss 1.3292
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 704 Loss 1.3635
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 705 Loss 1.3312
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 706 Loss 1.2962
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 707 Loss 1.2860
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 708 Loss 1.4055
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 709 Loss 1.2959
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 710 Loss 1.3695
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 711 Loss 1.3201
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 712 Loss 1.3125
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 713 Loss 1.2796
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 714 Loss 1.3694
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 715 Loss 1.3138
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 716 Loss 1.3407
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 717 Loss 1.3798
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 718 Loss 1.4919
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 719 Loss 1.3193
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 720 Loss 1.3911
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 721 Loss 1.3071
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 722 Loss 1.3153
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 723 Loss 1.3158
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 724 Loss 1.3812
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 725 Loss 1.4738
# INPUT:  (64, 11)
# (64, 17)
# Epoch 1 Batch 726 Loss 1.3018
# Epoch 1 Loss 1.5454
# Time taken for 1 epoch 262.4731819629669 sec
#
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 0 Loss 1.2227
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 1 Loss 1.3161
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 2 Loss 1.3057
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 3 Loss 1.2688
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 4 Loss 1.3180
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 5 Loss 1.2821
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 6 Loss 1.1976
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 7 Loss 1.2625
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 8 Loss 1.3907
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 9 Loss 1.2214
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 10 Loss 1.2975
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 11 Loss 1.2953
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 12 Loss 1.3788
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 13 Loss 1.2639
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 14 Loss 1.2713
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 15 Loss 1.2926
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 16 Loss 1.2353
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 17 Loss 1.3237
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 18 Loss 1.2122
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 19 Loss 1.2093
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 20 Loss 1.2194
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 21 Loss 1.2783
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 22 Loss 1.2825
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 23 Loss 1.2211
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 24 Loss 1.2947
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 25 Loss 1.3650
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 26 Loss 1.3857
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 27 Loss 1.1709
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 28 Loss 1.2112
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 29 Loss 1.2813
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 30 Loss 1.2393
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 31 Loss 1.2521
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 32 Loss 1.2210
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 33 Loss 1.2182
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 34 Loss 1.3605
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 35 Loss 1.3751
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 36 Loss 1.2884
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 37 Loss 1.2509
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 38 Loss 1.2881
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 39 Loss 1.2241
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 40 Loss 1.2473
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 41 Loss 1.1877
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 42 Loss 1.1923
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 43 Loss 1.2189
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 44 Loss 1.2301
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 45 Loss 1.3318
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 46 Loss 1.2571
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 47 Loss 1.3190
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 48 Loss 1.3103
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 49 Loss 1.2514
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 50 Loss 1.2256
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 51 Loss 1.3089
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 52 Loss 1.1822
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 53 Loss 1.2403
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 54 Loss 1.3680
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 55 Loss 1.3021
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 56 Loss 1.2652
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 57 Loss 1.2494
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 58 Loss 1.3442
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 59 Loss 1.2103
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 60 Loss 1.3252
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 61 Loss 1.1789
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 62 Loss 1.2443
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 63 Loss 1.2943
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 64 Loss 1.2931
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 65 Loss 1.2487
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 66 Loss 1.2925
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 67 Loss 1.3304
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 68 Loss 1.2894
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 69 Loss 1.2739
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 70 Loss 1.2493
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 71 Loss 1.2031
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 72 Loss 1.3026
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 73 Loss 1.2462
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 74 Loss 1.2553
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 75 Loss 1.3793
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 76 Loss 1.2424
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 77 Loss 1.2614
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 78 Loss 1.3124
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 79 Loss 1.2734
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 80 Loss 1.2647
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 81 Loss 1.2129
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 82 Loss 1.2541
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 83 Loss 1.2481
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 84 Loss 1.2479
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 85 Loss 1.2952
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 86 Loss 1.2681
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 87 Loss 1.2682
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 88 Loss 1.1832
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 89 Loss 1.2848
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 90 Loss 1.2940
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 91 Loss 1.2248
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 92 Loss 1.2080
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 93 Loss 1.3127
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 94 Loss 1.2325
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 95 Loss 1.3151
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 96 Loss 1.2506
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 97 Loss 1.2317
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 98 Loss 1.2746
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 99 Loss 1.3267
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 100 Loss 1.2705
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 101 Loss 1.1971
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 102 Loss 1.2301
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 103 Loss 1.2691
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 104 Loss 1.2476
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 105 Loss 1.3435
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 106 Loss 1.2372
# INPUT:  (64, 11)
# (64, 17)
# Epoch 2 Batch 107 Loss 1.3183
# INPUT:  (64, 11)
# (64, 17)
# ...
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 13 Loss 1.1383
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 14 Loss 1.1342
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 15 Loss 1.1619
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 16 Loss 1.1261
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 17 Loss 1.1530
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 18 Loss 1.0565
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 19 Loss 1.1457
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 20 Loss 1.1520
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 21 Loss 1.2024
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 22 Loss 1.1840
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 23 Loss 1.1901
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 24 Loss 1.2524
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 25 Loss 1.2289
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 26 Loss 1.1158
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 27 Loss 1.1232
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 28 Loss 1.0821
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 29 Loss 1.1128
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 30 Loss 1.1296
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 31 Loss 1.2199
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 32 Loss 1.1775
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 33 Loss 1.1624
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 34 Loss 1.1327
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 35 Loss 1.1973
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 36 Loss 1.2179
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 37 Loss 1.1991
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 38 Loss 1.2199
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 39 Loss 1.1567
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 40 Loss 1.1216
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 41 Loss 1.1672
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 42 Loss 1.1203
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 43 Loss 1.1746
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 44 Loss 1.1998
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 45 Loss 1.2257
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 46 Loss 1.1933
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 47 Loss 1.2183
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 48 Loss 1.1612
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 49 Loss 1.1663
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 50 Loss 1.1276
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 51 Loss 1.1169
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 52 Loss 1.1080
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 53 Loss 1.1591
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 54 Loss 1.1268
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 55 Loss 1.1427
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 56 Loss 1.1782
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 57 Loss 1.1383
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 58 Loss 1.1275
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 59 Loss 1.1650
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 60 Loss 1.1600
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 61 Loss 1.1415
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 62 Loss 1.2372
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 63 Loss 1.1728
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 64 Loss 1.0879
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 65 Loss 1.1549
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 66 Loss 1.1732
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 67 Loss 1.1965
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 68 Loss 1.1936
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 69 Loss 1.2151
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 70 Loss 1.0958
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 71 Loss 1.1349
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 72 Loss 1.1704
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 73 Loss 1.1913
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 74 Loss 1.1866
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 75 Loss 1.1754
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 76 Loss 1.1126
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 77 Loss 1.1307
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 78 Loss 1.2083
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 79 Loss 1.1493
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 80 Loss 1.0923
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 81 Loss 1.2239
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 82 Loss 1.1471
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 83 Loss 1.2090
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 84 Loss 1.1695
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 85 Loss 1.0925
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 86 Loss 1.1014
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 87 Loss 1.1596
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 88 Loss 1.1615
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 89 Loss 1.1156
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 90 Loss 1.1713
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 91 Loss 1.1123
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 92 Loss 1.1704
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 93 Loss 1.1841
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 94 Loss 1.1497
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 95 Loss 1.1953
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 96 Loss 1.1472
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 97 Loss 1.1898
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 98 Loss 1.0986
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 99 Loss 1.1496
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 100 Loss 1.1309
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 101 Loss 1.0886
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 102 Loss 1.1455
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 103 Loss 1.1385
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 104 Loss 1.2073
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 105 Loss 1.1445
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 106 Loss 1.1314
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 107 Loss 1.1778
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 108 Loss 1.1788
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 109 Loss 1.0994
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 110 Loss 1.1304
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 111 Loss 1.1225
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 112 Loss 1.1710
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 113 Loss 1.0996
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 114 Loss 1.0973
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 115 Loss 1.1784
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 116 Loss 1.1562
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 117 Loss 1.1645
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 118 Loss 1.2065
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 119 Loss 1.1750
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 120 Loss 1.1208
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 121 Loss 1.1585
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 122 Loss 1.0947
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 123 Loss 1.1620
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 124 Loss 1.1387
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 125 Loss 1.1414
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 126 Loss 1.2389
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 127 Loss 1.1558
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 128 Loss 1.1476
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 129 Loss 1.2345
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 130 Loss 1.1822
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 131 Loss 1.1744
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 132 Loss 1.1796
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 133 Loss 1.1722
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 134 Loss 1.1518
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 135 Loss 1.1293
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 136 Loss 1.1289
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 137 Loss 1.1885
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 138 Loss 1.1619
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 139 Loss 1.0662
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 140 Loss 1.1795
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 141 Loss 1.2219
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 142 Loss 1.1126
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 143 Loss 1.1589
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 144 Loss 1.1602
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 145 Loss 1.1477
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 146 Loss 1.1339
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 147 Loss 1.2661
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 148 Loss 1.1314
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 149 Loss 1.1836
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 150 Loss 1.1720
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 151 Loss 1.1463
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 152 Loss 1.1030
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 153 Loss 1.1551
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 154 Loss 1.1241
# INPUT:  (64, 11)
# (64, 17)
# Epoch 3 Batch 155 Loss 1.1877
# INPUT:  (64, 11)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-0775c82ac7a7> in <cell line: 1>()
#       8
#       9       for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
# ---> 10           batch_loss = train_step(inp, targ)
#      11           total_loss += batch_loss
#      12           print(targ.shape)
#
# <ipython-input-27-2f5728afed43> in train_step(inp, targ)
#      31           for t in range(1, targ.shape[1]):
#      32               # passing enc_output to the decoder
# ---> 33               prob_dist, dec_hidd, weights = decoder(sample_output, dec_input, dec_hidd )
#      34               loss += loss_function(targ[:, t], prob_dist)
#      35               # using teacher forcing
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1147                     self._compute_dtype_object
#    1148                 ):
# -> 1149                     outputs = call_fn(inputs, *args, **kwargs)
#    1150
#    1151                 if self._activity_regularizer:
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      94         bound_signature = None
#      95         try:
# ---> 96             return fn(*args, **kwargs)
#      97         except Exception as e:
#      98             if hasattr(e, "_keras_call_info_injected"):
#
# <ipython-input-20-019a5dfd9a54> in call(self, enc_output, dec_input, dec_internal_state)
#      33
#      34         # Embed the decoder input
# ---> 35         embed_dec_input=self.embedding(dec_input)
#      36
#      37         # Context + input = input to the GRU
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1147                     self._compute_dtype_object
#    1148                 ):
# -> 1149                     outputs = call_fn(inputs, *args, **kwargs)
#    1150
#    1151                 if self._activity_regularizer:
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      94         bound_signature = None
#      95         try:
# ---> 96             return fn(*args, **kwargs)
#      97         except Exception as e:
#      98             if hasattr(e, "_keras_call_info_injected"):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py in call(self, inputs)
#     270             out = tf.matmul(one_hot_data, self.embeddings)
#     271         else:
# --> 272             out = tf.nn.embedding_lookup(self.embeddings, inputs)
#     273
#     274         if self.sparse and not isinstance(out, tf.SparseTensor):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
# -> 1260         return dispatch_target(*args, **kwargs)
#    1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/embedding_ops.py in embedding_lookup_v2(params, ids, max_norm, name)
#     432     ValueError: If `params` is empty.
#     433   """
# --> 434   return embedding_lookup(params, ids, "div", name, max_norm=max_norm)
#     435
#     436
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
# -> 1260         return dispatch_target(*args, **kwargs)
#    1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/embedding_ops.py in embedding_lookup(params, ids, partition_strategy, name, validate_indices, max_norm)
#     360     """
#     361
# --> 362   return _embedding_lookup_and_transform(
#     363       params=params,
#     364       ids=ids,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/embedding_ops.py in _embedding_lookup_and_transform(params, ids, partition_strategy, name, max_norm, transform_fn)
#     146       with _colocate_with(params[0]):
#     147         result = _clip(
# --> 148             array_ops.gather(params[0], ids, name=name), ids, max_norm)
#     149         if transform_fn:
#     150           result = transform_fn(result)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
# -> 1260         return dispatch_target(*args, **kwargs)
#    1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     586                 'in a future version' if date is None else ('after %s' % date),
#     587                 instructions)
# --> 588       return func(*args, **kwargs)
#     589
#     590     doc = _add_deprecated_arg_notice_to_docstring(
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/array_ops.py in gather(***failed resolving arguments***)
#    5236     # TODO(apassos) find a less bad way of detecting resource variables
#    5237     # without introducing a circular dependency.
# -> 5238     return params.sparse_read(indices, name=name)
#    5239   except AttributeError:
#    5240     return gen_array_ops.gather_v2(params, indices, axis, name=name)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/resource_variable_ops.py in sparse_read(self, indices, name)
#     862     with ops.name_scope("Gather" if name is None else name) as name:
#     863       variable_accessed(self)
# --> 864       value = gen_resource_variable_ops.resource_gather(
#     865           self.handle, indices, dtype=self._dtype, name=name)
#     866
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/gen_resource_variable_ops.py in resource_gather(resource, indices, dtype, batch_dims, validate_indices, name)
#     609   if tld.is_eager:
#     610     try:
# --> 611       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     612         _ctx, "ResourceGather", name, resource, indices, "batch_dims",
#     613         batch_dims, "validate_indices", validate_indices, "dtype", dtype)
#
# KeyboardInterrupt:

# %%
checkpoint.save(file_prefix = checkpoint_prefix)

# %%
max_seq_length = 20
#Now we will generate the translation of the input sentence

def evaluate(sentence):

    sentence = preprocess_sentence(sentence)
    print(sentence)
    sentence = inp_lang.texts_to_sequences([sentence])
    print(sentence)
    len_sent=len(sentence[0])
    # Pad the sentence to the max_length_inp

    sentence = tf.keras.preprocessing.sequence.pad_sequences(sentence,
                                                            maxlen=max_length_inp,
                                                            padding='post')

    sentence = tf.convert_to_tensor(sentence)

    hidden_initialize = encoder.initialize_hidden_state()

    sentence = tf.convert_to_tensor([sentence]*BATCH_SIZE)
    sentence = tf.squeeze(sentence)
    print(sentence.shape)

    enc_output, enc_hidden = encoder(sentence, hidden_initialize)
    dec_input = tf.expand_dims([targ_lang.word_index['<start>']]* BATCH_SIZE, 1)
    dec_hidd = enc_hidden
    result = []
    #Disable teacher forcing
    attention_graph=[]
    for i in range(max_seq_length):
        prob_dist, dec_hidd, weights = decoder(sample_output, dec_input, dec_hidd )
        predicted_id = tf.argmax(prob_dist[0]).numpy()
        attention_graph.append(weights)
        result.append(targ_lang.index_word[predicted_id])

        if targ_lang.index_word[predicted_id] == '<end>':
            returnd=(attention_graph,result,len_sent)
            return returnd

        # the predicted ID is fed back into the model
        dec_input = tf.expand_dims([predicted_id] * BATCH_SIZE, 0)
        dec_input = tf.transpose(dec_input)
        print(dec_input.shape)

    returnd=(attention_graph,result,len_sent)
    return returnd


resultas = evaluate("Good.")

attend, result, len_inp = resultas[0], resultas[1], resultas[2]

# %%
print(len(result))

# %%
print(attend[0].shape)

# %%
new_attend=[]
for i in range(len(attend)):
    new_attend.append(attend[i][0][:len_inp])

# %%
print(len_inp)

# %%
print(len(new_attend))

# %%
print(new_attend[0].shape)

# %%
new_attend=np.array(new_attend)

# %%
print(new_attend)

# %%
print(result)
